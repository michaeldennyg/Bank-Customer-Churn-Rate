# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_url = r"C:\Users\micha\Bank Customer Churn Prediction\Bank Customer Churn Prediction.csv"

# %%
df = pd.read_csv(csv_url, index_col=0)
df.head(25)
# Out:
#              credit_score  country  gender  age  tenure    balance  \
# customer_id
# 15634602              619   France  Female   42       2       0.00
# 15647311              608    Spain  Female   41       1   83807.86
# 15619304              502   France  Female   42       8  159660.80
# 15701354              699   France  Female   39       1       0.00
# 15737888              850    Spain  Female   43       2  125510.82
# 15574012              645    Spain    Male   44       8  113755.78
# 15592531              822   France    Male   50       7       0.00
# 15656148              376  Germany  Female   29       4  115046.74
# 15792365              501   France    Male   44       4  142051.07
# 15592389              684   France    Male   27       2  134603.88
# 15767821              528   France    Male   31       6  102016.72
# 15737173              497    Spain    Male   24       3       0.00
# 15632264              476   France  Female   34      10       0.00
# 15691483              549   France  Female   25       5       0.00
# 15600882              635    Spain  Female   35       7       0.00
# 15643966              616  Germany    Male   45       3  143129.41
# 15737452              653  Germany    Male   58       1  132602.88
# 15788218              549    Spain  Female   24       9       0.00
# 15661507              587    Spain    Male   45       6       0.00
# 15568982              726   France  Female   24       6       0.00
# 15577657              732   France    Male   41       8       0.00
# 15597945              636    Spain  Female   32       8       0.00
# 15699309              510    Spain  Female   38       4       0.00
# 15725737              669   France    Male   46       3       0.00
# 15625047              846   France  Female   38       5       0.00
#
#              products_number  credit_card  active_member  estimated_salary  \
# customer_id
# 15634602                   1            1              1         101348.88
# 15647311                   1            0              1         112542.58
# 15619304                   3            1              0         113931.57
# 15701354                   2            0              0          93826.63
# 15737888                   1            1              1          79084.10
# 15574012                   2            1              0         149756.71
# 15592531                   2            1              1          10062.80
# 15656148                   4            1              0         119346.88
# 15792365                   2            0              1          74940.50
# 15592389                   1            1              1          71725.73
# 15767821                   2            0              0          80181.12
# 15737173                   2            1              0          76390.01
# 15632264                   2            1              0          26260.98
# 15691483                   2            0              0         190857.79
# 15600882                   2            1              1          65951.65
# 15643966                   2            0              1          64327.26
# 15737452                   1            1              0           5097.67
# 15788218                   2            1              1          14406.41
# 15661507                   1            0              0         158684.81
# 15568982                   2            1              1          54724.03
# 15577657                   2            1              1         170886.17
# 15597945                   2            1              0         138555.46
# 15699309                   1            1              0         118913.53
# 15725737                   2            0              1           8487.75
# 15625047                   1            1              1         187616.16
#
#              churn
# customer_id
# 15634602         1
# 15647311         0
# 15619304         1
# 15701354         0
# 15737888         0
# 15574012         1
# 15592531         0
# 15656148         1
# 15792365         0
# 15592389         0
# 15767821         0
# 15737173         0
# 15632264         0
# 15691483         0
# 15600882         0
# 15643966         0
# 15737452         1
# 15788218         0
# 15661507         0
# 15568982         0
# 15577657         0
# 15597945         0
# 15699309         1
# 15725737         0
# 15625047         0

# %%
df.describe()
# Out:
#        credit_score           age        tenure        balance  \
# count  10000.000000  10000.000000  10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288
# std       96.653299     10.487806      2.892174   62397.405202
# min      350.000000     18.000000      0.000000       0.000000
# 25%      584.000000     32.000000      3.000000       0.000000
# 50%      652.000000     37.000000      5.000000   97198.540000
# 75%      718.000000     44.000000      7.000000  127644.240000
# max      850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# std           0.581654      0.45584       0.499797      57510.492818
# min           1.000000      0.00000       0.000000         11.580000
# 25%           1.000000      0.00000       0.000000      51002.110000
# 50%           1.000000      1.00000       1.000000     100193.915000
# 75%           2.000000      1.00000       1.000000     149388.247500
# max           4.000000      1.00000       1.000000     199992.480000
#
#               churn
# count  10000.000000
# mean       0.203700
# std        0.402769
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 15634602 to 15628319
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   credit_score      10000 non-null  int64
#  1   country           10000 non-null  object
#  2   gender            10000 non-null  object
#  3   age               10000 non-null  int64
#  4   tenure            10000 non-null  int64
#  5   balance           10000 non-null  float64
#  6   products_number   10000 non-null  int64
#  7   credit_card       10000 non-null  int64
#  8   active_member     10000 non-null  int64
#  9   estimated_salary  10000 non-null  float64
#  10  churn             10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 937.5+ KB

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['credit_score'], bins=1000, kde=True)
plt.title('Distribution of Credit Scores')
plt.show()

# %%
# Example for a single variable
plt.figure(figsize=(10, 6))
sns.countplot(x='credit_score', data=df)
plt.title('Count of Each Category')
plt.show()

# %%
# Select only numeric columns from the DataFrame
numeric_df = df.select_dtypes(include='number')

# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
